# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df1 = pd.read_csv("2022-05-02.csv")
df2 = pd.read_csv("2022-05-06.csv")
df3 = pd.read_csv("2022-05-08.csv")
df4 = pd.read_csv("2022-05-31.csv")

# %%
dfMain = pd.concat([df1, df2, df3, df4], axis = 0)
dfMain
# Out:
#                 Beginn                Ende  Anzahl der Aktivitätsminuten  \
# 0   00:00:00.000+05:30  00:15:00.000+05:30                           NaN
# 1   00:15:00.000+05:30  00:30:00.000+05:30                           1.0
# 2   00:30:00.000+05:30  00:45:00.000+05:30                           NaN
# 3   00:45:00.000+05:30  01:00:00.000+05:30                           NaN
# 4   01:00:00.000+05:30  01:15:00.000+05:30                           NaN
# ..                 ...                 ...                           ...
# 91  22:45:00.000+05:30  23:00:00.000+05:30                          14.0
# 92  23:00:00.000+05:30  23:15:00.000+05:30                           9.0
# 93  23:15:00.000+05:30  23:30:00.000+05:30                           9.0
# 94  23:30:00.000+05:30  23:45:00.000+05:30                          15.0
# 95  23:45:00.000+05:30  00:00:00.000+05:30                          14.0
#
#     Kalorien (kcal)  Distanz (m)  Kardiopunkte  Kardiominuten  \
# ...

# %%
df = dfMain.copy(deep = True)

# %%
sns.heatmap(df.isna())
# Out:
# <AxesSubplot:>

# %%
df.dropna(axis = 1, inplace = True)

# %%
df.reset_index(inplace = True, drop = True)

# %%
df
# Out:
#                  Beginn                Ende  Kalorien (kcal)
# 0    00:00:00.000+05:30  00:15:00.000+05:30        15.450521
# 1    00:15:00.000+05:30  00:30:00.000+05:30        15.450521
# 2    00:30:00.000+05:30  00:45:00.000+05:30        21.579005
# 3    00:45:00.000+05:30  01:00:00.000+05:30        17.918223
# 4    01:00:00.000+05:30  01:15:00.000+05:30        15.450520
# ..                  ...                 ...              ...
# 379  22:45:00.000+05:30  23:00:00.000+05:30        46.850156
# 380  23:00:00.000+05:30  23:15:00.000+05:30        35.626052
# 381  23:15:00.000+05:30  23:30:00.000+05:30        42.416709
# 382  23:30:00.000+05:30  23:45:00.000+05:30        64.599998
# 383  23:45:00.000+05:30  00:00:00.000+05:30        31.826525
#
# [384 rows x 3 columns]

# %%
index = pd.DataFrame(data = range(0, 384), columns = ["index"])

# %%
index
# Out:
#      index
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4
# ..     ...
# 379    379
# 380    380
# 381    381
# 382    382
# 383    383
#
# [384 rows x 1 columns]

# %%
df = pd.concat([index, df], axis = 1)
df
# Out:
#      index              Beginn                Ende  Kalorien (kcal)
# 0        0  00:00:00.000+05:30  00:15:00.000+05:30        15.450521
# 1        1  00:15:00.000+05:30  00:30:00.000+05:30        15.450521
# 2        2  00:30:00.000+05:30  00:45:00.000+05:30        21.579005
# 3        3  00:45:00.000+05:30  01:00:00.000+05:30        17.918223
# 4        4  01:00:00.000+05:30  01:15:00.000+05:30        15.450520
# ..     ...                 ...                 ...              ...
# 379    379  22:45:00.000+05:30  23:00:00.000+05:30        46.850156
# 380    380  23:00:00.000+05:30  23:15:00.000+05:30        35.626052
# 381    381  23:15:00.000+05:30  23:30:00.000+05:30        42.416709
# 382    382  23:30:00.000+05:30  23:45:00.000+05:30        64.599998
# 383    383  23:45:00.000+05:30  00:00:00.000+05:30        31.826525
#
# [384 rows x 4 columns]

# %%
sns.lineplot(y = "Kalorien (kcal)", x = "index", data = df)
# Out:
# <AxesSubplot:xlabel='index', ylabel='Kalorien (kcal)'>

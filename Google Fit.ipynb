# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_all = pd.read_csv('Tägliche Aktivitätswerte.csv')
df_all
# Out:
#           Datum  Anzahl der Aktivitätsminuten  Kalorien (kcal)   Distanz (m)  \
# 0    2021-01-08                           NaN       391.232563           NaN
# 1    2021-01-09                           NaN      1564.500015           NaN
# 2    2021-01-10                          32.0      1667.712891   1283.078246
# 3    2021-01-11                          20.0      1656.525290    786.421561
# 4    2021-01-12                          28.0      1642.704709    959.737564
# ..          ...                           ...              ...           ...
# 237  2022-07-01                         157.0      1797.368676   7316.024970
# 238  2022-07-02                         181.0      1876.325572   8411.493719
# 239  2022-07-03                         140.0      1786.201550   7194.493707
# 240  2022-07-04                         242.0      2020.381994  12128.564225
# 241  2022-07-05                          35.0       629.162444   1258.859055
#
# ...

# %%
pd.p

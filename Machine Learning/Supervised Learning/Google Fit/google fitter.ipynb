# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import json

# %%
stepsFile = open("Data/steps/derived_com.google.step_count.delta_com.google.json")
steps = json.load(stepsFile)
# Out:
# {'Data Source': 'derived:com.google.step_count.delta:com.google.android.fit:Xiaomi:Redmi 6 Pro:f719f9f0374bf0a2:top_level',
#  'Data Points': [{'fitValue': [{'value': {'intVal': 3}}],
#    'originDataSourceId': 'raw:com.google.step_count.cumulative:Xiaomi:Redmi 6 Pro:f719f9f0374bf0a2:Step Counter',
#    'endTimeNanos': 1644422553114747296,
#    'dataTypeName': 'com.google.step_count.delta',
#    'startTimeNanos': 1644422493114747296,
#    'modifiedTimeMillis': 1644467693998,
#    'rawTimestampNanos': 0},
#   {'fitValue': [{'value': {'intVal': 6}}],
#    'originDataSourceId': 'raw:com.google.step_count.cumulative:Xiaomi:Redmi 6 Pro:f719f9f0374bf0a2:Step Counter',
#    'endTimeNanos': 1644422614934266072,
#    'dataTypeName': 'com.google.step_count.delta',
#    'startTimeNanos': 1644422554934266072,
#    'modifiedTimeMillis': 1644467693998,
#    'rawTimestampNanos': 0},
#   {'fitValue': [{'value': {'intVal': 12}}],
# ...

# %%
stepsSteps = steps["Data Points"][1]["fitValue"][0]["value"]["intVal"]
stepsSteps
# Out:
# 6

# %%
stepsTime = steps["Data Points"][2]["endTimeNanos"]- steps["Data Points"][2]["startTimeNanos"]
stepsTime
# Out:
# 60000000000

# %%
steps["Data Points"][1].keys()
# Out:
# dict_keys(['fitValue', 'originDataSourceId', 'endTimeNanos', 'dataTypeName', 'startTimeNanos', 'modifiedTimeMillis', 'rawTimestampNanos'])
